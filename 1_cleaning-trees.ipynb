# %% [markdown]
# <h1 style="color: #e3db24;">00 | Libraries and Settings</h1>

# %%
# 📚 Basic libraries
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
from IPython.core.display import HTML

# %%
# ⚙️ Settings
pd.set_option('display.max_columns', None) # display all columns
pd.set_option('display.float_format', '{:,.2f}'.format)
import warnings
warnings.filterwarnings('ignore') # ignore warnings

# %% [markdown]
# <h1 style="color: #e3db24;">01 | Data Extraction and Exploration</h1>

# %%
data = pd.read_csv("https://geo.sv.rostock.de/download/opendata/baeume/baeume.csv") # data as of 5th December 2024

# %% [markdown]
# <h2 style="color: #ec7511;">Copy as Best Practice</h2>

# %%
df1 = data.copy()

# %% [markdown]
# <h2 style="color: #ec7511;">Exploring the Data (First Impressions)</h2>

# %%
df1.shape
# Out:
# (71069, 13)

# %%
df1.head()
# Out:
#    latitude  longitude                                  uuid  \
# 0     54.06      12.10  d04f4edf-c22b-481d-8140-f5da1203b9c7
# 1     54.05      12.10  9ac13cb1-d6fa-42ae-9374-0300965a97d7
# 2     54.07      12.12  253aad1a-c704-40fb-8401-7d88f94559d2
# 3     54.07      12.11  d7a4e358-8634-4497-988e-d2e51487d1cb
# 4     54.07      12.12  aa50bcd3-125c-43d5-9859-9afa368c73e0
#
#   gattung_botanisch gattung_deutsch     art_botanisch             art_deutsch  \
# 0              Acer           Ahorn  Acer platanoides             Spitz-Ahorn
# 1              Acer           Ahorn  Acer platanoides             Spitz-Ahorn
# 2           Quercus           Eiche     Quercus robur             Stiel-Eiche
# 3              Acer           Ahorn    Acer saccharum            Zucker-Ahorn
# 4           Quercus           Eiche     Quercus rubra  Amerikanische Roteiche
#
#    alleebaum  hoehe  stammdurchmesser  stammumfang  kronendurchmesser  \
# 0          0   8.00               NaN          NaN               6.00
# 1          0   8.00               NaN          NaN               6.00
# 2          0  18.00             35.00       109.96              12.00
# 3          0  20.00             50.93       160.00               9.20
# 4          1   9.00             31.83       100.00              10.00
#
#    baumpatenschaft
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
df1.sample(8)
# Out:
#        latitude  longitude                                  uuid  \
# 31860     54.08      12.07  243e80bc-993d-4ba6-a467-28a5acfd093a
# 23224     54.14      12.05  cca3f277-f623-40d0-a497-46d9e8e89a06
# 2901      54.12      12.14  2b33b922-929a-4169-8dad-9e196c805b45
# 5132      54.13      12.06  e6835b73-b479-4bd0-b079-35d1d06b535b
# 64852     54.08      12.16  5dde8f96-851d-4bf7-ba34-aa2684809670
# 51010     54.14      12.05  24dc053d-bbd8-4a55-9dcb-47a7f7319795
# 55967     54.17      12.08  4facf1c7-afb7-4bec-97a3-c82b971479a6
# 41918     54.15      12.07  0896a668-5c5f-42d1-bc26-3757fc753944
#
#       gattung_botanisch gattung_deutsch               art_botanisch  \
# 31860              Acer           Ahorn         Acer pseudoplatanus
# 23224             Tilia           Linde          Tilia platyphyllos
# 2901              Salix           Weide               Salix species
# 5132              Tilia           Linde          Tilia platyphyllos
# 64852            Betula           Birke    Betula pendula „Tristis“
# 51010             Tilia           Linde  Tilia cordata „Greenspire“
# 55967             Salix           Weide                  Salix alba
# 41918             Pinus          Kiefer               Pinus species
#
#                      art_deutsch  alleebaum  hoehe  stammdurchmesser  \
# 31860                 Berg-Ahorn          0   5.00              5.73
# 23224               Sommer-Linde          1  10.00             35.00
# 2901                       Weide          0   6.00             15.00
# 5132                Sommer-Linde          0   7.00             21.00
# 64852       Hängebirke „Tristis“          0   5.00             25.15
# 51010  Winter-Linde „Greenspire“          0   8.00             13.00
# 55967               Silber-Weide          0  15.00            109.00
# 41918                     Kiefer          0  13.00             34.00
#
#        stammumfang  kronendurchmesser  baumpatenschaft
# 31860        18.00               1.00                0
# 23224       109.96               7.50                0
# 2901         47.12               4.50                0
# 5132         65.97               4.00                0
# 64852        79.00               4.00                0
# 51010        40.84               4.00                0
# 55967       342.43               8.00                0
# 41918       106.81               6.00                0

# %%
df1.tail(10)
# Out:
#        latitude  longitude                                  uuid  \
# 71059     54.11      12.11  cb9e72fe-9818-43a4-b673-d396770beb73
# 71060     54.13      12.16  f8805e5c-0309-4d13-bb20-298a74ba0fee
# 71061     54.17      12.15  369c87df-3bde-4f71-bc70-58cde08bdd3f
# 71062     54.18      12.23  152a487a-75cc-449b-a123-1612a57a8497
# 71063     54.18      12.23  926f6eef-a750-4162-bf54-ce789618eeeb
# 71064     54.19      12.15  c835819d-ed3d-44c1-bd4f-e43d5921e8ee
# 71065     54.19      12.15  7b9698c5-aad2-41d4-8d21-e4e263a91c6b
# 71066     54.08      12.19  f08e588c-d4d9-4874-9554-c379881c3221
# 71067     54.20      12.15  fb63b8f4-6a80-48ac-933b-111c61a506a7
# 71068     54.19      12.35  9922e38b-ed44-4a88-bc07-f0fa61f963cb
#
#       gattung_botanisch gattung_deutsch         art_botanisch  \
# 71059           Populus          Pappel   Populus balsamifera
# 71060             Tilia           Linde         Tilia cordata
# 71061             Fagus           Buche       Fagus sylvatica
# 71062           Quercus           Eiche         Quercus robur
# 71063           Quercus           Eiche         Quercus robur
# 71064           Quercus           Eiche         Quercus robur
# 71065           Quercus           Eiche         Quercus robur
# 71066            Prunus         Kirsche          Prunus avium
# 71067             Pinus          Kiefer      Pinus sylvestris
# 71068           Robinia    Scheinakazie  Robinia pseudoacacia
#
#            art_deutsch  alleebaum  hoehe  stammdurchmesser  stammumfang  \
# 71059    Balsam-Pappel          0  25.00            115.23       362.00
# 71060     Winter-Linde          0  22.00             70.35       221.00
# 71061         Rotbuche          0  20.00             48.38       152.00
# 71062      Stiel-Eiche          0  21.00             73.85       232.00
# 71063      Stiel-Eiche          0  23.00             85.31       268.00
# 71064      Stiel-Eiche          0  25.00             76.39       240.00
# 71065      Stiel-Eiche          0  15.00             70.98       223.00
# 71066    Vogel-Kirsche          0  13.00             48.38       152.00
# 71067   Gemeine Kiefer          0  19.00             50.29       158.00
# 71068  Gemeine Robinie          0  20.00             94.22       296.00
#
#        kronendurchmesser  baumpatenschaft
# 71059              12.00                0
# 71060              12.00                0
# 71061               8.00                0
# 71062              12.00                0
# 71063              14.00                0
# 71064              14.00                0
# 71065              12.00                0
# 71066               7.00                0
# 71067               7.00                0
# 71068              13.00                0

# %%
df1.dtypes
# Out:
# latitude             float64
# longitude            float64
# uuid                  object
# gattung_botanisch     object
# gattung_deutsch       object
# art_botanisch         object
# art_deutsch           object
# alleebaum              int64
# hoehe                float64
# stammdurchmesser     float64
# stammumfang          float64
# kronendurchmesser    float64
# baumpatenschaft        int64
# dtype: object

# %%
df1.nunique()
# Out:
# latitude             71054
# longitude            71054
# uuid                 71069
# gattung_botanisch       85
# gattung_deutsch         85
# art_botanisch          477
# art_deutsch            469
# alleebaum                2
# hoehe                  201
# stammdurchmesser       826
# stammumfang            842
# kronendurchmesser      282
# baumpatenschaft          2
# dtype: int64

# %%
df1.columns
# Out:
# Index(['latitude', 'longitude', 'uuid', 'gattung_botanisch', 'gattung_deutsch',
#        'art_botanisch', 'art_deutsch', 'alleebaum', 'hoehe',
#        'stammdurchmesser', 'stammumfang', 'kronendurchmesser',
#        'baumpatenschaft'],
#       dtype='object')

# %% [markdown]
# <h3 style="color: #ec300e;">First Impressions</h3>
#
# The dataset is called [**Bäume (trees)**](https://www.govdata.de/suche/daten/baume) and was downloaded from the **Data Portal for Germany** ([GOVDATA](https://www.govdata.de/) – Das Datenportal für Deutschland) where a lot of open data regarding different topics can be found and downloaded.
#
# - The names of the columns and much information within the dataset are in German (the columns which will be used for the analysis will be **translated to English** right at the beginning of the cleaning process, categories will follow when it is necessary for understanding).
# - The data was last updated on **5th December 2024**.
# - The dataset contains **13 columns and over 71,000 rows**, each row seems to be **describing one specific tree**.
# - Two columns indicate the **location** of the specific tree ("latitude" and "longitude"), four columns contain information regarding the **genus and species** of the tree (German and botanic name), four columns describe **measuring values** of the tree (height, diameter of trunk and crown, circumference of trunk). Lastly, there are two binary coded columns which show whether a tree is an **alley tree** and whether it was adopted/ there is a **sponsorship** for this tree.
# - Five columns are of **datatype object** and contain string data, one of these is a **unique identifier** and the other four are **nominal categorial** data. All the other columns are numerical with differences regarding their datatype and their nature: Two columns are **integers**, they are **binary coded nominal categorial** data. The remaining six columns are **float**, two of them are **categorial data** (latitude and longitude) and four **continuous numerical** data describing the measurements of the tree.
# - The continuous numerical data is displayed in **different units**: two in meter, two in centimeter.

# %% [markdown]
# <h1 style="color: #e3db24;">02 | Data Cleaning</h1>

# %% [markdown]
# <h2 style="color: #ec7511;">Dropping unnecessary columns</h2>

# %% [markdown]
# <h3 style="color: #ec300e;">Making a Copy before Further Steps</h3>

# %%
df2 = df1.copy()

# %% [markdown]
# <h3 style="color: #ec300e;">Next Steps</h3>

# %%
# checking "uuid", it is a unique identifier which can be dropped
df2.uuid.nunique()
# Out:
# 71069

# %%
# dropping German names and keeping only botanical terms
df2.drop(columns=["gattung_deutsch", "art_deutsch", "uuid"], inplace=True)

# %% [markdown]
# <h3 style="color: #ec300e;">Changing all string to lowercase</h3>

# %%
# to simplify cleaning and analysing categorial (string) data, all entries will be cleaned of capital letters
df2 = df2.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
df2.sample(3)
# Out:
#        latitude  longitude gattung_botanisch         art_botanisch  alleebaum  \
# 2436      54.13      12.06           robinia  robinia pseudoacacia          0
# 45000     54.08      12.09           robinia  robinia pseudoacacia          0
# 51583     54.09      12.12            betula        betula pendula          0
#
#        hoehe  stammdurchmesser  stammumfang  kronendurchmesser  \
# 2436   10.00             49.34       155.00              10.00
# 45000  25.00             50.93       160.00               9.00
# 51583  19.00             22.28        70.00               7.00
#
#        baumpatenschaft
# 2436                 0
# 45000                0
# 51583                0

# %% [markdown]
# <h2 style="color: #ec7511;">Renaiming the Columns</h2>

# %%
# renaiming columns regarding their content and using the English language and snakecase:
df2.rename(columns= {"latitude": "lat",
                     "longitude": "long",
                     "gattung_botanisch": "genus",
                     "art_botanisch": "species",
                     "alleebaum": "alley_tree",
                     "hoehe": "height",
                     "stammdurchmesser": "trunk_diameter",
                     "stammumfang": "trunk_circumference",
                     "kronendurchmesser": "crown_diameter",
                     "baumpatenschaft": "sponsorship" }, inplace=True)

# %% [markdown]
# <h2 style="color: #ec7511;">Dealing with Specific Columns: Units, Outliers</h2>

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #b8daff;
#     border-radius: 4px;
#     background-color: #0eec75;
#     color: #004085;
#     font-size: 16px;
#     line-height: 1.5;
#     word-wrap: break-word;
#     text-align: left;">
#     <strong>Info:</strong> The trunk diameter column will also be dropped because circumference is the slightly more reliable measured value, and both are very dependent on one another. The additional info from keeping both cannot be seen.
# </div>

# %%
# dropping trunk_diameter
df2.drop(columns=["trunk_diameter"], inplace=True)

# %%
df2.shape
# Out:
# (71069, 9)

# %%
df2.sample(5)
# Out:
#         lat  long     genus             species  alley_tree  height  \
# 38518 54.18 12.05  fraxinus  fraxinus excelsior           0   11.00
# 43150 54.08 12.10     tilia  tilia platyphyllos           1   18.00
# 53522 54.19 12.15     picea         picea abies           0   10.00
# 37931 54.13 12.06     tilia       tilia cordata           0    8.00
# 15048 54.15 12.05     ulmus       ulmus species           0   14.00
#
#        trunk_circumference  crown_diameter  sponsorship
# 38518                51.00            3.00            0
# 43150               163.36            7.00            0
# 53522                82.00            5.00            0
# 37931                76.00            6.00            0
# 15048                81.68            7.00            0

# %%
# checking describe after very first cleaning
df2.describe()
# Out:
#             lat      long  alley_tree    height  trunk_circumference  \
# count 71,069.00 71,069.00   71,069.00 69,626.00            69,428.00
# mean      54.11     12.11        0.17     12.35               102.89
# std        0.04      0.04        0.38      7.71                85.46
# min       54.00     12.01        0.00      0.40                 0.16
# 25%       54.08     12.07        0.00      7.00                53.41
# 50%       54.10     12.10        0.00     11.00                87.96
# 75%       54.14     12.14        0.00     16.00               135.09
# max       54.25     12.35        1.00    814.00             8,130.44
#
#        crown_diameter  sponsorship
# count       69,533.00    71,069.00
# mean             6.42         0.00
# std              5.44         0.05
# min              0.10         0.00
# 25%              4.00         0.00
# 50%              6.00         0.00
# 75%              8.00         0.00
# max            710.00         1.00

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #b8daff;
#     border-radius: 4px;
#     background-color: #0eec75;
#     color: #004085;
#     font-size: 16px;
#     line-height: 1.5;
#     word-wrap: break-word;
#     text-align: left;">
#     <strong>Info:</strong> The columns height and crown_diameter are encoded in meter, but the column trunk_circumference is encoded in centimeter. Please see the file "metadaten_baeume.rdf.txt" in the GitHub repo for this project for more info on meta data. The values of the column trunk_circumference will be changed to meter as well to allow better analysation and comparison with the other metric data.
# </div>

# %%
# converting 'trunk_circumference' from cm to m
df2['trunk_circumference'] = df2['trunk_circumference'] / 100

# %% [markdown]
# <div style="
#     padding: 10px;
#     margin: 10px 0;
#     border: 1px solid #ffeeba;
#     border-radius: 4px;
#     background-color: #e3db24;
#     color: #bb1066;
#     line-height: 1.5;
#     word-wrap: break-word;">
#     <strong>Be Aware:</strong> There are some curiosities in the data regarding the max values and also the means. In two of the columns which contain measurements of the trees (height and crown_diameter), the numbers cannot possibly be right (i.e. max height of over 814 m or max crown diameter of 710 m). A reason for this could be a different numerical encoding or wrong data entries. I will therefore check the values of these two columns separately.
# </div>

# %% [markdown]
# <h2 style="color: #ec7511;">Checking Outliers in All Three Continuous Numerical Columns</h2>

# %%
trees_measure = df2[["height", "trunk_circumference", "crown_diameter"]]

# %%
# histograms for all columns which contain measurements of the trees

color = '#0eec75'

# grid size
nrows, ncols = 2,2  # adjust for your number of features

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(10, 8))

axes = axes.flatten()

# Plot each numerical feature
for i, ax in enumerate(axes):
    if i >= len(trees_measure.columns):
        ax.set_visible(False)  # hide uneased plots
        continue
    ax.hist(trees_measure.iloc[:, i], bins=5, color=color, edgecolor='black')
    ax.set_title(trees_measure.columns[i])

plt.tight_layout()
plt.show()

# %%
# boxplots for these columns (in different diagramms because of the very different scales)

color = '#0eece8'

# grid size
nrows, ncols = 2,2

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(10,8))

axes = axes.flatten()

for i, ax in enumerate(axes):
    if i >= len(trees_measure.columns):
        ax.set_visible(False)
        continue
    ax.boxplot(trees_measure.iloc[:, i].dropna(), vert=False, patch_artist=True, 
               boxprops=dict(facecolor=color, color='black'), 
               medianprops=dict(color='yellow'), whiskerprops=dict(color='black'), 
               capprops=dict(color='black'), flierprops=dict(marker='o', color='red', markersize=5))
    ax.set_title(trees_measure.columns[i], fontsize=10)
    ax.tick_params(axis='x', labelsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #b8daff;
#     border-radius: 4px;
#     background-color: #0eece8;
#     color: #004085;
#     font-size: 16px;
#     line-height: 1.5;
#     word-wrap: break-word;
#     text-align: left;">
#     <strong>Conclusions:</strong> From the histograms and especially from the boxplots, we can see that there are many outliers at the higher end of the values. The <strong>extreme values seem very unlikely</strong>, this must be because of <strong>wrong data entries</strong> because the existence of trees with these measurements are not possible. The faulty entries could either be a missing "." to separate numbers correctly or entirely wrong. To explore this more deeply, I will now look into these two columns and then decide how to proceed.
# </div>

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #f7b70d;
#     border-radius: 4px;
#     background-color: #e2ee1e;
#     color: #060606;
#     font-size: 16px;
#     line-height: 1.5;
#     word-wrap: break-word;
#     text-align: left;">
#     <strong>Next Steps: How to Deal with Faulty Data Entry</strong>
# <p>After researching the maximum realistic values for height, trunk circumference and crown diameter of many of these species, it is clear that these extreme values <strong>cannot be correct</strong>. I will deal with this as follows: extract the maximum values per species from the dataset, let ChatGPT compare these to sources online and then <strong>replace values</strong> in the three columns which are not possible for this species of tree with the <strong>median</strong> values of the other trees of this specific species (or genus for cases in which ChatGPT could not find sources for the specific species). I will limit this filter to only the categories in species which have the 100 highest values in each column because the others seem realistic measures and I have to make a cut somewhere.</p>
# <p>Please note: unclear categories like "Verschiedene oder Baumart unbekannt" will be dealt with later and ignored for now</p>
# </div>

# %% [markdown]
# <h3 style="color: #ec300e;">1: Column "height"</h3>

# %%
# filtering rows in which 'height' > 30
height_30 = df2[df2['height'] > 30]
height_30.sort_values("height", ascending=False)
# Out:
#         lat  long    genus               species  alley_tree  height  \
# 4208  54.17 12.05    tilia    tilia platyphyllos           0  814.00
# 61509 54.13 12.17  populus  populus x canadensis           0  275.00
# 12823 54.17 12.01  populus         populus nigra           0  224.00
# 47411 54.09 12.13     acer          acer species           0  205.00
# 47088 54.18 12.09     acer          acer species           0  175.00
# ...     ...   ...      ...                   ...         ...     ...
# 32500 54.08 12.18     acer          acer species           0   30.50
# 16417 54.09 12.12    tilia         tilia species           1   30.50
# 16415 54.08 12.12    tilia         tilia species           1   30.50
# 16147 54.08 12.12    tilia         tilia species           1   30.50
# 16116 54.08 12.12    tilia         tilia species           1   30.10
#
#        trunk_circumference  crown_diameter  sponsorship
# 4208                  1.89            8.00            0
# 61509                 2.17            9.50            0
# 12823                 1.45           10.00            0
# 47411                 1.57           10.50            0
# 47088                  NaN           16.00            0
# ...                    ...             ...          ...
# 32500                 1.13           11.00            0
# 16417                 1.60            9.00            0
# 16415                 2.10            6.50            0
# 16147                 1.82            8.50            0
# 16116                 2.51            9.00            0
#
# [1201 rows x 9 columns]

# %%
max_values_height_per_species = df2.groupby("species")["height"].max()
max_values_height_per_species.sort_values(ascending=False)[:50]
# Out:
# species
# tilia platyphyllos                  814.00
# populus x canadensis                275.00
# populus nigra                       224.00
# acer species                        205.00
# quercus robur                       125.00
# betula pendula                      117.00
# acer pseudoplatanus                 115.00
# tilia tomentosa                     105.00
# acer rubrum                          89.00
# fagus sylvatica                      80.00
# aesculus hippocastanum               75.00
# malus domestica                      75.00
# quercus species                      59.00
# acer ginnala                         57.00
# acer platanoides                     55.00
# fraxinus excelsior                   55.00
# malus sylvestris                     45.00
# tilia cordata                        45.00
# sorbus intermedia                    45.00
# abies grandis                        41.00
# populus species                      40.00
# tilia species                        39.00
# windschutz laub-mischbestand         38.00
# fagus species                        38.00
# picea species                        37.00
# pinus species                        37.00
# aesculus species                     36.00
# pseudotsuga menziesii                36.00
# populus x canadensis „regenerata“    35.00
# larix species                        35.00
# populus balsamifera                  35.00
# acer platanoides „globosum“          35.00
# thuja species                        35.00
# castanea sativa                      34.50
# quercus rubra                        34.00
# picea abies                          34.00
# robinia species                      33.50
# populus nigra „italica“              33.00
# salix species                        33.00
# carpinus betulus                     33.00
# ulmus species                        32.50
# abies species                        32.00
# betula species                       32.00
# fagus sylvatica „purpurea“           32.00
# platanus species                     32.00
# aesculus flava                       32.00
# buchen-eichen-mischwald              31.00
# larix kaempferi                      31.00
# prunus mahaleb                       30.00
# prunus avium                         30.00
# Name: height, dtype: float64

# %%
max_values_height_per_species = df2.groupby("species")["height"].max()
max_values_height_per_species.sort_values(ascending=False)[50:100]
# Out:
# species
# fraxinus species                       30.00
# robinia pseudoacacia                   30.00
# populus tremula                        30.00
# buchen-nadel-mischbestand              30.00
# ulmus glabra                           30.00
# salix alba                             30.00
# sequoiadendron giganteum               30.00
# fagus sylvatica „pendula“              30.00
# populus alba                           30.00
# pinus sylvestris                       30.00
# acer campestre                         30.00
# windschutz pappel mit unterpflanzung   30.00
# weichholz-weidenbestand                30.00
# verschiedene oder baumart unbekannt    30.00
# pappelbestand                          29.00
# ailanthus altissima                    29.00
# salix alba „tristis“                   29.00
# ulmus carpinifolia                     29.00
# sorbus species                         28.00
# liriodendron tulipifera                28.00
# larix decidua                          28.00
# acer saccharum                         28.00
# quercus robur „fastigiata“             28.00
# pinus nigra                            28.00
# picea omorika                          28.00
# betula pubescens                       27.00
# pseudotsuga menziesii var. glauca      27.00
# lärchen-laub-mischwald                 27.00
# picea orientalis                       27.00
# robinien-ahorn-mischbestand            27.00
# abies alba                             27.00
# acer saccharinum                       26.00
# quercus cerris                         26.00
# populus                                26.00
# alnus species                          26.00
# ahorn-linde mischbestand               25.00
# chamaecyparis lawsoniana               25.00
# acer negundo                           25.00
# salix nigra                            25.00
# larix x eurolepsis                     25.00
# acer pseudoplatanus „atropurpureum“    25.00
# populus simonii                        25.00
# tsuga canadensis                       25.00
# prunusbestand                          25.00
# alnus glutinosa                        25.00
# pseudotsuga species                    25.00
# carpinus species                       25.00
# fichten-mischbestand                   25.00
# picea pungens „glauca“                 25.00
# bruchwald erle mischbestand            25.00
# Name: height, dtype: float64

# %%
# storing maximal realistic heights per species in a dictionary
species_height_limits = {
    "tilia platyphyllos": 44.0,
    "populus x canadensis": 38.5,
    "populus nigra": 33.0,
    "acer species": 33.0,
    "quercus robur": 38.5,
    "betula pendula": 33.0,
    "acer pseudoplatanus": 38.5,
    "tilia tomentosa": 33.0,
    "acer rubrum": 27.5,
    "fagus sylvatica": 38.5,
    "aesculus hippocastanum": 27.5,
    "malus domestica": 11.0,
    "quercus species": 33.0,
    "acer ginnala": 11.0,
    "acer platanoides": 27.5,
    "fraxinus excelsior": 38.5,
    "malus sylvestris": 11.0,
    "tilia cordata": 33.0,
    "sorbus intermedia": 16.5
}

# %%
# function to filter out the data which is most likely faulty
def replace_outliers_height_with_median(group):
    species = group.name
    limit = species_height_limits.get(species, float('inf'))  # no limit if species is not in dictionary
    mask = group > limit
    median_value = group[~mask].median()  # median of valid values
    group[mask] = median_value  # replacing unrealistic values
    return group

# Werte in "height" nach Kategorien in "species" verarbeiten
df2['height'] = df2.groupby('species')['height'].transform(replace_outliers_height_with_median)

# %%
# checking result
max_values_height_per_species = df2.groupby("species")["height"].max()
max_values_height_per_species.sort_values(ascending=False)[:10]
# Out:
# species
# abies grandis                  41.00
# populus species                40.00
# tilia species                  39.00
# populus x canadensis           38.00
# windschutz laub-mischbestand   38.00
# fagus species                  38.00
# pinus species                  37.00
# picea species                  37.00
# aesculus species               36.00
# pseudotsuga menziesii          36.00
# Name: height, dtype: float64

# %% [markdown]
# <h3 style="color: #ec300e;">2: Column "trunk_circumference"</h3>

# %%
# filtering rows in which 'trunk_circumference' > 3
trunk_3 = df2[df2['trunk_circumference'] > 3]
trunk_3.sort_values("trunk_circumference", ascending=False)
# Out:
#         lat  long     genus           species  alley_tree  height  \
# 41410 54.12 12.15     tilia     tilia cordata           1    7.00
# 5456  54.14 12.07   quercus     quercus robur           0    6.00
# 68795 54.12 12.06  aesculus  aesculus species           0   19.00
# 41590 54.11 12.16     tilia     tilia cordata           1    8.00
# 57762 54.12 12.04   quercus   quercus species           0   12.00
# ...     ...   ...       ...               ...         ...     ...
# 16387 54.08 12.12     tilia     tilia species           1   25.00
# 16396 54.08 12.12     tilia     tilia species           1   31.00
# 50375 54.07 12.09     abies     abies grandis           0   25.00
# 16672 54.08 12.12      acer      acer species           0   31.00
# 56498 54.10 12.11     salix        salix alba           0   13.00
#
#        trunk_circumference  crown_diameter  sponsorship
# 41410                81.30            7.00            0
# 5456                 78.54            5.40            0
# 68795                51.63           12.00            0
# 41590                35.66            8.00            0
# 57762                23.75            4.00            0
# ...                    ...             ...          ...
# 16387                 3.02           16.50            0
# 16396                 3.02           14.00            0
# 50375                 3.02            8.00            0
# 16672                 3.02           17.00            0
# 56498                 3.01           10.00            0
#
# [994 rows x 9 columns]

# %%
max_values_trunk_per_species = df2.groupby("species")["trunk_circumference"].max()
max_values_trunk_per_species.sort_values(ascending=False)[:50]
# Out:
# species
# tilia cordata                    81.30
# quercus robur                    78.54
# aesculus species                 51.63
# quercus species                  23.75
# tilia species                    18.42
# betula pendula                   13.33
# salix species                    12.57
# pinus species                    11.15
# pinus nigra                      10.18
# populus species                  10.00
# fichten-mischbestand              9.42
# acer platanoides „globosum“       8.79
# acer negundo                      8.17
# acer pseudoplatanus               8.01
# sorbus intermedia                 7.47
# sequoiadendron giganteum          7.41
# fraxinus excelsior                7.36
# salix alba                        7.07
# aesculus x carnea                 6.40
# pterocarya fraxinifolia           5.97
# populus nigra                     5.80
# acer saccharinum                  5.65
# salix nigra                       5.65
# robinia pseudoacacia              5.62
# corylus colurna                   5.62
# acer platanoides                  5.37
# aesculus hippocastanum            5.34
# weichholz-weidenbestand           5.29
# alnus species                     4.90
# quercus rubra                     4.87
# tilia platyphyllos                4.78
# salix caprea                      4.71
# prunus avium                      4.71
# chamaecyparis lawsoniana          4.71
# platanus x acerifolia             4.57
# fagus sylvatica „purpurea“        4.54
# fraxinus species                  4.50
# acer campestre                    4.40
# fagus sylvatica „laciniata“       4.30
# abies grandis                     4.27
# carpinus species                  4.08
# populus nigra „italica“           4.08
# fagus species                     3.93
# acer species                      3.90
# windschutz laub-mischbestand      3.80
# fagus sylvatica                   3.80
# populus x canadensis „robusta“    3.80
# alnus glutinosa                   3.79
# populus balsamifera               3.62
# larix species                     3.60
# Name: trunk_circumference, dtype: float64

# %%
max_values_trunk_per_species = df2.groupby("species")["trunk_circumference"].max()
max_values_trunk_per_species.sort_values(ascending=False)[50:100]
# Out:
# species
# populus x canadensis                   3.57
# quercus cerris                         3.55
# ulmus species                          3.52
# robinia species                        3.46
# picea omorika                          3.46
# larix decidua                          3.46
# crataegus species                      3.46
# larix x eurolepsis                     3.36
# pinus sylvestris                       3.33
# salix alba „tristis“                   3.30
# abies species                          3.27
# castanea sativa                        3.27
# salix matsudana „tortuosa“             3.25
# abies concolor                         3.24
# castanea species                       3.24
# pseudotsuga menziesii                  3.20
# carpinus betulus                       3.20
# ulmus laevis                           3.20
# fagus sylvatica „pendula“              3.17
# malus species                          3.17
# picea orientalis                       3.17
# prunus domestica „aggregat“            3.14
# tilia tomentosa                        3.14
# picea species                          3.14
# acer rubrum „scanlon“                  3.14
# salix viminalis                        3.14
# populus                                3.14
# ulmus glabra                           3.14
# acer saccharum                         3.10
# populus x canadensis „regenerata“      3.05
# fichten-kiefer-mischbestand            3.02
# larix kaempferi                        3.00
# sorbus aria                            2.98
# pinus mugo                             2.98
# liriodendron tulipifera                2.98
# ahornbestand                           2.98
# rhus species                           2.98
# populus tremula                        2.89
# platanus species                       2.89
# prunus cerasifera                      2.89
# pappelbestand                          2.84
# buchen-eichen-mischwald                2.83
# windschutz pappel mit unterpflanzung   2.83
# taxodium distichum                     2.83
# prunus domestica                       2.83
# ulmus carpinifolia                     2.80
# catalpa bignonioides                   2.73
# aesculus flava                         2.73
# picea abies                            2.70
# cedrus atlantica                       2.70
# Name: trunk_circumference, dtype: float64

# %%
# storing maximal realistic trunk cirumferences per species in a dictionary
species_trunk_limits = {
    "tilia cordata": 7.7,
    "quercus robur": 8.25,
    "aesculus species": 5.5,
    "quercus species": 2.75,
    "tilia species": 3.3,
    "betula pendula": 3.85,
    "salix species": 3.52,
    "pinus species": 3.08,
    "pinus nigra": 2.97,
    "populus species": 3.3,
    "fichten-mischbestand": 3.3,
    "acer platanoides „globosum“": 1.1,
    "acer negundo": 2.75,
    "acer pseudoplatanus": 2.75,
    "sorbus intermedia": 1.98
}

# %%
# function to filter out the data which is most likely faulty
def replace_outliers_trunk_with_median(group):
    species = group.name
    limit = species_trunk_limits.get(species, float('inf'))  # no limit if species is not in dictionary
    mask = group > limit
    median_value = group[~mask].median()  # median of valid values
    group[mask] = median_value  # replacing unrealistic values
    return group

# Werte in "trunk_circumference" nach Kategorien in "species" verarbeiten
df2['trunk_circumference'] = df2.groupby('species')['trunk_circumference'].transform(replace_outliers_trunk_with_median)

# %%
# checking result
max_values_trunk_per_species.sort_values(ascending=False)[:10]
# Out:
# species
# tilia cordata      81.30
# quercus robur      78.54
# aesculus species   51.63
# quercus species    23.75
# tilia species      18.42
# betula pendula     13.33
# salix species      12.57
# pinus species      11.15
# pinus nigra        10.18
# populus species    10.00
# Name: trunk_circumference, dtype: float64

# %% [markdown]
# <h3 style="color: #ec300e;">3: Column "crown_diameter"</h3>

# %%
# filtering rows in which 'crown_diameter' > 15
crown_diameter_15 = df2[df2['crown_diameter'] > 15]
crown_diameter_15.sort_values("crown_diameter", ascending=False)
# Out:
#         lat  long      genus               species  alley_tree  height  \
# 68943 54.09 12.13       acer      acer platanoides           0   15.00
# 65306 54.12 12.05  ailanthus   ailanthus altissima           0   16.00
# 65029 54.12 12.06   fraxinus    fraxinus excelsior           0   15.00
# 61476 54.13 12.17    populus  populus x canadensis           0   34.00
# 67670 54.10 12.09       acer      acer platanoides           0   16.00
# ...     ...   ...        ...                   ...         ...     ...
# 43362 54.08 12.09      fagus         fagus species           0   21.00
# 47769 54.18 12.08    quercus         quercus robur           0   20.00
# 47016 54.18 12.08      fagus         fagus species           0   30.00
# 42936 54.07 12.12    quercus         quercus rubra           0   13.00
# 42820 54.07 12.17      tilia         tilia cordata           0   23.00
#
#        trunk_circumference  crown_diameter  sponsorship
# 68943                 0.87          710.00            0
# 65306                 1.36          610.00            0
# 65029                 0.81          411.00            0
# 61476                 1.42          164.00            0
# 67670                 1.86          138.00            0
# ...                    ...             ...          ...
# 43362                 2.60           15.20            0
# 47769                 2.26           15.20            0
# 47016                 1.60           15.10            0
# 42936                 1.67           15.10            0
# 42820                 2.25           15.10            0
#
# [1428 rows x 9 columns]

# %%
max_values_crown_diameter_per_species = df2.groupby("species")["crown_diameter"].max()
max_values_crown_diameter_per_species.sort_values(ascending=False)[:50]
# Out:
# species
# acer platanoides                       710.00
# ailanthus altissima                    610.00
# fraxinus excelsior                     411.00
# populus x canadensis                   164.00
# betula species                         114.00
# tilia cordata                           95.00
# acer pseudoplatanus                     87.00
# platanus x acerifolia                   84.20
# acer species                            80.60
# aesculus hippocastanum                  70.00
# betula pendula                          69.00
# robinia species                         58.00
# verschiedene oder baumart unbekannt     55.00
# sorbus aria                             49.00
# populus species                         45.00
# sorbus species                          45.00
# sorbus intermedia                       44.00
# salix species                           40.00
# tilia platyphyllos                      37.00
# crataegus laevigata „paul’s scarlet“    34.00
# quercus petraea                         34.00
# fraxinus species                        34.00
# populus nigra                           31.00
# fagus sylvatica                         30.00
# quercus species                         28.50
# acer negundo                            28.00
# quercus robur                           26.00
# salix alba                              25.00
# fagus sylvatica „pendula“               25.00
# salix nigra                             23.00
# acer saccharum                          23.00
# quercus rubra                           23.00
# fagus species                           22.50
# ahornbestand                            22.00
# platanus species                        21.50
# acer saccharinum                        21.00
# salix alba „tristis“                    21.00
# larix species                           21.00
# fagus sylvatica „purpurea“              20.00
# tilia tomentosa                         20.00
# populus                                 20.00
# robinia pseudoacacia                    20.00
# salix caprea                            20.00
# prunus mahaleb                          20.00
# carpinus betulus                        20.00
# populus balsamifera                     20.00
# tilia species                           20.00
# aesculus species                        19.00
# alnus glutinosa                         18.00
# populus x canadensis „regenerata“       18.00
# Name: crown_diameter, dtype: float64

# %%
max_values_crown_diameter_per_species.sort_values(ascending=False)[50:100]
# Out:
# species
# populus alba                           18.00
# juglans regia                          18.00
# acer carpinifolium                     18.00
# larix decidua                          18.00
# acer campestre                         18.00
# weichholz-weidenbestand                18.00
# liriodendron tulipifera                18.00
# malus domestica                        18.00
# larix x eurolepsis                     17.50
# ulmus laevis                           17.00
# morus alba                             16.20
# ulmus species                          16.00
# sequoiadendron giganteum               16.00
# prunus species                         16.00
# abies species                          16.00
# pinus species                          16.00
# picea abies                            16.00
# taxus baccata                          16.00
# larix kaempferi                        16.00
# fichten-kiefer-mischbestand            16.00
# quercus cerris                         16.00
# ulmus glabra                           16.00
# fagus sylvatica „laciniata“            16.00
# windschutz laub-mischbestand           16.00
# pinus nigra                            15.00
# hedera helix                           15.00
# populus simonii                        15.00
# ulmus carpinifolia                     15.00
# ailanthus species                      15.00
# robinia pseudoacacia „umbraculifera“   15.00
# prunus avium                           15.00
# platanus hispanica                     15.00
# prunus cerasifera                      15.00
# carpinus species                       15.00
# salix viminalis                        15.00
# tilia cordata „greenspire“             15.00
# windschutz pappel mit unterpflanzung   15.00
# prunusbestand                          15.00
# pappelbestand                          15.00
# alnus species                          15.00
# quercus robur „fastigiata aurea“       15.00
# betula pubescens                       15.00
# robinien-ahorn-mischbestand            14.50
# syringa vulgaris                       14.50
# salix fragilis                         14.00
# tilia x euchlora                       14.00
# prunus serrulata „kanzan“              14.00
# populus lasiocarpa                     14.00
# sophora japonica                       14.00
# populus tremula                        14.00
# Name: crown_diameter, dtype: float64

# %%
# storing maximal values of crown diameters per species in a dictionary
species_crown_limits = {
    "acer platanoides": 33.00,
    "ailanthus altissima": 22.00,
    "fraxinus excelsior": 27.50,
    "populus x canadensis": 18.04,
    "betula species": 12.54,
    "tilia cordata": 10.45,
    "acer pseudoplatanus": 9.57,
    "platanus x acerifolia": 9.26,
    "acer species": 8.87,
    "aesculus hippocastanum": 7.7,
    "betula pendula": 7.59,
    "robinia species": 6.38,
    "sorbus aria": 5.39,
    "populus species": 4.95,
    "sorbus species": 4.95,
    "sorbus intermedia": 4.84,
    "salix species": 4.4,
    "tilia platyphyllos": 4.07,
    "crataegus laevigata 'paul’s scarlet'": 3.74,
    "quercus petraea": 3.74,
    "fraxinus species": 3.74,
    "populus nigra": 3.41,
    "fagus sylvatica": 3.3,
    "quercus species": 3.14,
    "acer negundo": 3.08,
    "quercus robur": 2.86,
    "salix alba": 2.75,
    "fagus sylvatica 'pendula'": 2.75,
    "salix nigra": 2.53,
    "acer saccharum": 2.53,
    "quercus rubra": 2.53,
    "fagus species": 2.48,
    "ahornbestand": 2.42,
    "platanus species": 2.37,
    "acer saccharinum": 2.31,
    "salix alba 'tristis'": 2.31,
    "larix species": 2.31,
    "fagus sylvatica 'purpurea'": 2.2,
    "tilia tomentosa": 2.2,
    "populus": 2.2,
    "robinia pseudoacacia": 2.2,
    "salix caprea": 2.2,
    "prunus mahaleb": 2.2,
    "carpinus betulus": 2.2,
    "populus balsamifera": 2.2,
    "tilia species": 2.2,
    "aesculus species": 2.09,
    "alnus glutinosa": 1.98,
    "populus x canadensis 'regenerata'": 1.98,
    "populus alba": 1.98,
    "juglans regia": 1.98,
    "acer carpinifolium": 1.98,
    "larix decidua": 1.98,
    "acer campestre": 1.98,
    "weichholz-weidenbestand": 1.98,
    "liriodendron tulipifera": 1.98,
    "malus domestica": 1.98,
    "larix x eurolepsis": 1.93,
    "ulmus laevis": 1.87,
    "morus alba": 1.78,
    "ulmus species": 1.76,
    "sequoiadendron giganteum": 1.76,
    "prunus species": 1.76,
    "abies species": 1.76,
    "pinus species": 1.76,
    "picea abies": 1.76,
    "taxus baccata": 1.76,
    "larix kaempferi": 1.76,
    "fichten-kiefer-mischbestand": 1.76,
    "quercus cerris": 1.76,
    "ulmus glabra": 1.76,
    "fagus sylvatica 'laciniata'": 1.76,
    "windschutz laub-mischbestand": 1.76,
    "pinus nigra": 1.65,
    "hedera helix": 1.65,
    "populus simonii": 1.65,
    "ulmus carpinifolia": 1.65,
    "ailanthus species": 1.65,
    "robinia pseudoacacia 'umbraculifera'": 1.65,
    "prunus avium": 1.65,
    "platanus hispanica": 1.65,
    "prunus cerasifera": 1.65,
    "carpinus species": 1.65,
    "salix viminalis": 1.65,
    "tilia cordata 'greenspire'": 1.65,
    "windschutz pappel mit unterpflanzung": 1.65,
    "prunusbestand": 1.65,
    "pappelbestand": 1.65,
    "alnus species": 1.65,
    "quercus robur 'fastigiata aurea'": 1.65,
    "betula pubescens": 1.65,
    "robinien-ahorn-mischbestand": 1.6,
    "syringa vulgaris": 1.6,
    "salix fragilis": 1.54,
    "tilia x euchlora": 1.54,
    "prunus serrulata 'kanzan'": 1.54,
    "populus lasiocarpa": 1.54,
    "sophora japonica": 1.54,
    "populus tremula": 1.54
}

# %%
# function to filter out the data which is most likely faulty
def replace_outliers_crown_with_median(group):
    species = group.name
    limit = species_crown_limits.get(species, float('inf'))  # no limit if species is not in dictionary
    mask = group > limit
    median_value = group[~mask].median()  # median of valid values
    group[mask] = median_value  # replacing unrealistic values
    return group

# Werte in "crown_diameter" nach Kategorien in "species" verarbeiten
df2['crown_diameter'] = df2.groupby('species')['crown_diameter'].transform(replace_outliers_crown_with_median)

# %%
# checking result
max_values_crown_diameter_per_species = df2.groupby("species")["crown_diameter"].max()
max_values_crown_diameter_per_species.sort_values(ascending=False)[:20]
# Out:
# species
# verschiedene oder baumart unbekannt    55.00
# crataegus laevigata „paul’s scarlet“   34.00
# fagus sylvatica „pendula“              25.00
# fraxinus excelsior                     25.00
# salix alba „tristis“                   21.00
# fagus sylvatica „purpurea“             20.00
# acer platanoides                       20.00
# populus x canadensis                   18.00
# populus x canadensis „regenerata“      18.00
# fagus sylvatica „laciniata“            16.00
# ailanthus altissima                    16.00
# tilia cordata „greenspire“             15.00
# quercus robur „fastigiata aurea“       15.00
# robinia pseudoacacia „umbraculifera“   15.00
# taxus species                          14.00
# pinus sylvestris                       14.00
# salix matsudana „tortuosa“             14.00
# corylus colurna                        14.00
# buchen-eichen-mischwald                14.00
# castanea sativa                        14.00
# Name: crown_diameter, dtype: float64

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #b8daff;
#     border-radius: 4px;
#     background-color: #0eece8;
#     color: #004085;
#     font-size: 16px;
#     line-height: 1.5;
#     word-wrap: break-word;
#     text-align: left;">
#     <strong>Conclusions Cleaning Tree Measures:</strong> All unrealistic data was cleaned by replacing the values which seemed faulty with the median of the specific species. Through this, no data was lost. There is some uncertainty left as to whether it was the best way to replace unlikely values with the median values of that species. For the most extreme values, it seems likely that a punctuation was missing. Yet for other values, this was not so clear. As this could not be shown for certain, I decided to use the median values which seemed to be the best way to get the closest to real data.
# </div>

# %% [markdown]
# <h2 style="color: #ec7511;">Analysing the Relation between Genus and Species</h2>

# %% [markdown]
# <h3 style="color: #ec300e;">Making a Copy</h3>

# %%
df3 = df2.copy()

# %%
# unique values in species per genus
for genus, group in df3.groupby('genus'):
    print(f"Genus: {genus}")
    print(group['species'].nunique())  # number of unqiue values in species
    print(group['species'].unique()) # unique values
    print("-" * 50)
# Out:
# Genus: abies
# 10
# ['abies procera' 'abies grandis' 'abies alba' 'abies concolor'
#  'abies nordmanniana' 'abies balsamea' 'abies species' 'abies homolepis'
#  'abies cephalonica' 'abies procera „glauca“']
# --------------------------------------------------
# Genus: acer
# 42
# ['acer platanoides' 'acer saccharum' 'acer pseudoplatanus' 'acer species'
#  'acer ginnala' 'acer pseudoplatanus „bruchem“' 'acer campestre'
#  'acer negundo' 'acer platanoides „deborah“'
#  'acer campestre „huiberts elegant“' 'acer saccharinum'
#  'acer campestre „elsrijk“' 'acer platanoides „laciniatum“' 'acer opalus'
#  'acer platanoides „olmstedt“' 'acer platanoides „fairview“'
#  'acer platanoides „cleveland“' 'acer tataricum' 'acer rubrum'
#  'acer pseudoplatanus „erectum“' 'acer davidii'
#  'acer platanoides „globosum“' 'acer rubrum „scanlon“'
#  'acer platanoides „emerald queen“' 'acer platanoides „schwedleri“'
#  'acer platanoides „allershausen“' 'acer platanoides „apollo“'
#  'acer rubrum „red sunset“' 'acer pseudoplatanus „atropurpureum“'
#  'acer platanoides „columnaris“' 'acer platanoides „crimson sentry“'
#  'acer platanoides „acer platanoides“' 'acer platanoide „farlake’s green“'
#  'acer platanoides „royal red“' 'acer pseudoplatanus „purpurascens“'
#  'acer palmatum' 'acer rufinerve' 'acer carpinifolium' 'acer japonicum'
#  'acer negundo „aureo-variegatum“' 'acer hersii'
#  'acer rubrum „autumn blaze“']
# --------------------------------------------------
# Genus: aesculus
# 6
# ['aesculus species' 'aesculus x carnea' 'aesculus x carnea „briotii“'
#  'aesculus hippocastanum' 'aesculus flava'
#  'aesculus hippocastanum „baumannii“']
# --------------------------------------------------
# Genus: ailanthus
# 2
# ['ailanthus altissima' 'ailanthus species']
# --------------------------------------------------
# Genus: alnus
# 5
# ['alnus glutinosa' 'alnus incana' 'alnus cordata' 'alnus spaethii'
#  'alnus species']
# --------------------------------------------------
# Genus: amelanchier
# 3
# ['amelanchier arborea „robin hill“' 'amelanchier lamarckii'
#  'amelanchier species']
# --------------------------------------------------
# Genus: araucaria
# 1
# ['araucaria auraucana']
# --------------------------------------------------
# Genus: betula
# 13
# ['betula species' 'betula pendula' 'betula pubescens' 'betula utilis'
#  'betula papyrifera' 'betula albosinensis' 'betula pendula „tristis“'
#  'betula pendula „youngii“' 'betula pendula „fastigata“'
#  'betula maximowicziana' 'betula nigra' 'betula pendula „dalecarlica“'
#  'betula ermanii']
# --------------------------------------------------
# Genus: broussonetia
# 1
# ['broussonetia papyrifera']
# --------------------------------------------------
# Genus: buxus
# 1
# ['buxus sempervirens']
# --------------------------------------------------
# Genus: carpinus
# 5
# ['carpinus betulus' 'carpinus species' 'carpinus betulus „fastigiata“'
#  'carpinus betulus „frans fontaine“' 'carpinus betulus „lucas“']
# --------------------------------------------------
# Genus: carya
# 1
# ['carya species']
# --------------------------------------------------
# Genus: castanea
# 2
# ['castanea sativa' 'castanea species']
# --------------------------------------------------
# Genus: catalpa
# 3
# ['catalpa bignonioides' 'catalpa species' 'catalpa bignonioides „aurea“']
# --------------------------------------------------
# Genus: cedrus
# 4
# ['cedrus libani' 'cedrus atlantica' 'cedrus atlantica „glauca“'
#  'cedrus deodara']
# --------------------------------------------------
# Genus: celtis
# 1
# ['celtis australis']
# --------------------------------------------------
# Genus: cercidiphyllum
# 1
# ['ceridiphyllum japonicum']
# --------------------------------------------------
# Genus: cercis
# 1
# ['cercis siliquastrum']
# --------------------------------------------------
# Genus: chamaecyparis
# 4
# ['chamaecyparis lawsoniana' 'chamaecyparis species'
#  'chamaecyparis lawsoniana „glauca“' 'chamaecyparis nootkatensis']
# --------------------------------------------------
# Genus: cornus
# 4
# ['cornus kousa' 'cornus mas' 'cornus species' 'cornus florida']
# --------------------------------------------------
# Genus: corylus
# 4
# ['corylus colurna' 'corylus species' 'corylus avellana'
#  'corylus avellana „fuscorubra“']
# --------------------------------------------------
# Genus: crataegus
# 9
# ['crataegus laevigata „paul’s scarlet“' 'crataegus monogyna'
#  'crataegus x prunifolia' 'crataegus species' 'crataegus crus-galli'
#  'crataegus laevigata' 'crataegus x lavallei'
#  'crataegus lavallei „carrierei“' 'crataegus phaenopyrum']
# --------------------------------------------------
# Genus: cryptomeria
# 1
# ['cryptomeria japonica']
# --------------------------------------------------
# Genus: cupressus
# 1
# ['cupressus species']
# --------------------------------------------------
# Genus: cydonia
# 1
# ['cydonia oblonga']
# --------------------------------------------------
# Genus: elaeagnus
# 2
# ['elaeagnus species' 'elaeagnus angustifolia']
# --------------------------------------------------
# Genus: euonymus
# 1
# ['euonymus europaeus']
# --------------------------------------------------
# Genus: fagus
# 9
# ['fagus species' 'fagus sylvatica' 'fagus sylvatica „dawyck“'
#  'fagus sylvatica „purpurea“' 'fagus sylvatica „pendula“'
#  'fagus sylvatica „fastigata“' 'fagus sylvatica „atropunicea pendula“'
#  'fagus sylvatica „atropunicea“' 'fagus sylvatica „laciniata“']
# --------------------------------------------------
# Genus: fraxinus
# 13
# ['fraxinus species' 'fraxinus excelsior' 'fraxinus ornus'
#  'fraxinus pennsylvanica „summit“' 'fraxinus ornus „rotterdam“'
#  'fraxinus ornus „louisa lady“' 'fraxinus pennsylvanica'
#  'fraxinus excelsior „westhof’s glorie“' 'fraxinus americana'
#  'fraxinus excelsior „diversifolia“' 'fraxinus angustifolia „raywood“'
#  'fraxinus excelsior „golden desert“' 'fraxinus angustifolia']
# --------------------------------------------------
# Genus: ginkgo
# 2
# ['ginkgo biloba' 'ginkgo biloba „princeton sentry“']
# --------------------------------------------------
# Genus: gleditsia
# 3
# ['gleditsia triacanthos „skyline“' 'gleditsia triacanthos'
#  'gleditsia triacanthos „shademaster“']
# --------------------------------------------------
# Genus: gruppenbäume
# 21
# ['fichten-kiefer-mischbestand' 'windschutz laub-mischbestand'
#  'ahorn-laub-mischbestand' 'bruchwald erle mischbestand' 'ahornbestand'
#  'birken-weichholz-bestand' 'pappelbestand' 'weichholz-weidenbestand'
#  'buchen-eichen-mischwald' 'fichten-mischbestand' 'prunusbestand'
#  'buchen-nadel-mischbestand' 'koniferen- nadelholzbestand'
#  'robinienbestand' 'windschutz pappel mit unterpflanzung'
#  'robinien-ahorn-mischbestand' 'erlenbestand' 'ahorn-linde mischbestand'
#  'buchen reinbestand' 'rotdornbestand' 'lärchen-laub-mischwald']
# --------------------------------------------------
# Genus: gymnocladus
# 1
# ['gymnocladus dioicus']
# --------------------------------------------------
# Genus: halesia
# 1
# ['halesia monticola']
# --------------------------------------------------
# Genus: hedera
# 1
# ['hedera helix']
# --------------------------------------------------
# Genus: hippophae
# 1
# ['hippophae rhamnoides']
# --------------------------------------------------
# Genus: idesia
# 1
# ['idesia polycarpa']
# --------------------------------------------------
# Genus: ilex
# 2
# ['ilex aquifolium' 'ilex species']
# --------------------------------------------------
# Genus: juglans
# 4
# ['juglans nigra' 'juglans regia' 'juglans species'
#  'juglans regia „seifersdorfer runde“']
# --------------------------------------------------
# Genus: juniperus
# 4
# ['juniperus chinensis' 'juniperus communis' 'juniperus species'
#  'juniperus sabina']
# --------------------------------------------------
# Genus: koelreuteria
# 1
# ['koelreuteria paniculata']
# --------------------------------------------------
# Genus: laburnum
# 4
# ['laburnum anagyroides' 'laburnum species' 'laburnum x water „vossii“'
#  'laburnum alpinum']
# --------------------------------------------------
# Genus: larix
# 4
# ['larix decidua' 'larix kaempferi' 'larix species' 'larix x eurolepsis']
# --------------------------------------------------
# Genus: liquidambar
# 5
# ['liquidambar styraciflua' 'liquidambar species'
#  'liquidambar styraciflua „worplesdon“' 'liqidambar styraciflua „paarl“'
#  'liquidambar styraciflua „moraine“']
# --------------------------------------------------
# Genus: liriodendron
# 1
# ['liriodendron tulipifera']
# --------------------------------------------------
# Genus: magnolia
# 4
# ['magnolia kobus' 'magnolia species' 'magnolia stellata'
#  'magnolia x soulangiana']
# --------------------------------------------------
# Genus: malus
# 48
# ['malus domestica „resi“' 'malus domestica „schöner von boskoop“'
#  'malus species' 'malus sylvestris' 'malus tschonoskii'
#  'eriolobus trilobatus' 'malus domestica „redcats“'
#  'malus domestica „suncats“' 'malus floribunda'
#  'malus domestica „goldparmäne“' 'malus domestica „james grieve“'
#  'malus domenstica „starcats“' 'malus domestica „florina“'
#  'malus „evereste“' 'malus floribunda „hillieri“'
#  'malus domestica „gelber richard“' 'malus domestica „weißer klarapfel“'
#  'malus domestica' 'malus domestica „auralia“'
#  'malus domestica „drüwken traubenapfel“'
#  'malus domestica „signe tillisch“' 'malus domestica „cox orange“'
#  'malus „aggregat“' 'malus prunifolia' 'malus x purpurea'
#  'malus domestica „ribston pepping“'
#  'malus domestica „große kasseler renette“' 'malus domestica „jonathan“'
#  'malus domestica „kaiser wilhelm“' 'malus floribunda „david“'
#  'malus domestica „macoun“' 'malus domestica „carola“'
#  'malus domestica „pommersche krummstiel“' 'malus „red sentinel“'
#  'malus x moerlandsii' 'malus domenstica „altländer pfannkuchenapfel“'
#  'malus domestica „dülmener rosenapfel“'
#  'malus domestica „rote sternrenette“' 'malus domestica „hasenkopf“'
#  'malus pumila' 'malus domestica „grahams jubiläumsapfel“'
#  'malus domestica „seestermüher zitronenapfel“'
#  'malus domestica „gravensteiner“'
#  'malus domestica „prinz albrecht von preußen“'
#  'malus domestica „jakob fischer“' 'malus domestica „doberaner renette“'
#  'malus domestica „graue französische renette“' 'malus x „rudolph“']
# --------------------------------------------------
# Genus: metasequoia
# 1
# ['metasequoia glyptostroboides']
# --------------------------------------------------
# Genus: morus
# 3
# ['morus nigra' 'morus alba' 'morus alba „nana“']
# --------------------------------------------------
# Genus: nyssa
# 1
# ['nyssa sylvatica']
# --------------------------------------------------
# Genus: ostrya
# 1
# ['ostrya carpinifolia']
# --------------------------------------------------
# Genus: parrotia
# 1
# ['parrotia persica']
# --------------------------------------------------
# Genus: paulownia
# 1
# ['paulownia tomentosa']
# --------------------------------------------------
# Genus: picea
# 10
# ['picea species' 'picea abies' 'picea pungens „glauca“' 'picea sitchensis'
#  'picea omorika' 'picea orientalis' 'picea pungens' 'picea nigra'
#  'picea breweriana' 'picea omorica']
# --------------------------------------------------
# Genus: pinus
# 12
# ['pinus species' 'pinus nigra' 'pinus sylvestris' 'pinus ponderosa'
#  'pinus jeffreyi' 'pinus strobus' 'pinus nigra ssp. nigra' 'pinus mugo'
#  'pinus peuce' 'pinus mugo mughus' 'pinus cembra' 'pinus leucodermis']
# --------------------------------------------------
# Genus: platanus
# 4
# ['platanus x acerifolia' 'platanus species' 'platanus orientalis'
#  'platanus hispanica']
# --------------------------------------------------
# Genus: populus
# 14
# ['populus species' 'populus nigra „italica“' 'populus nigra'
#  'populus tremula' 'populus alba' 'populus x canadensis' 'populus'
#  'populus x canescens' 'populus balsamifera' 'populus simonii'
#  'populus lasiocarpa' 'populus x canadensis „regenerata“'
#  'populus x canadensis „robusta“' 'populus alba „pyramidalis“']
# --------------------------------------------------
# Genus: prunus
# 39
# ['prunus species' 'prunus padus' 'prunus serrulata' 'prunus cerasifera'
#  'prunus avium' 'prunus serrulata „kanzan“' 'prunus domestica'
#  'prunus cerasus' 'prunus serrula' 'prunus cerasifera „nigra“'
#  'prunus x hilleri „spire“' 'prunus avium „plena“'
#  'prunus domestica „aggregat“' 'prunus spinosa' 'prunus avium „accolade“'
#  'prunus armeniaca' 'prunus serotina' 'prunus avium „burlat“'
#  'prunus dulcis' 'prunus syr. „miragrande“'
#  'prunus subhirtella „accolade“' 'prunus padus „albertii“'
#  'prunus laurocerasus' 'prunus serrulata „shirofugen“'
#  'prunus fructicosa „globasa“' 'prunus x cistena' 'prunus mahaleb'
#  'prunus padus „schloss tiefurt“' 'prunus serrulata „amanogawa“'
#  'prunus cerasifera „atropurpurea“' 'prunus serrulata „pink perfection“'
#  'prunus avium „aggregat“' 'prunus domestica „hauszwetsche“'
#  'prunus avium „große schwarze knorpelkirsche“'
#  'prunus domestica „hanita“' 'prunus sargentii' 'prunus x schmittii'
#  'prunus serotina „cartilaginea“'
#  'prunus domestica „graf althans reneklode“']
# --------------------------------------------------
# Genus: pseudotsuga
# 3
# ['pseudotsuga menziesii' 'pseudotsuga species'
#  'pseudotsuga menziesii var. glauca']
# --------------------------------------------------
# Genus: pterocarya
# 2
# ['pterocarya species' 'pterocarya fraxinifolia']
# --------------------------------------------------
# Genus: pyrus
# 20
# ['pyrus communis „decora“' 'pyrus communis „bergamotte“'
#  'pyrus communis „beech hill“' 'pyrus communis „gute luise“'
#  'pyrus species' 'pyrus pyraster' 'pyrus communis „williams christ“'
#  'pyrus calleryana' 'pyrus calleryana „chanticleer“'
#  'pyrus communis „köstliche von charneux“' 'pyrus communis'
#  'pyrus communis „gute graue“' 'pyrus communis „aggregat“'
#  'pyrus communis „concorde“' 'pyrus communis „clapps liebling“'
#  'pyrus communis „neue poiteau“' 'pyrus salicifolia'
#  'pyrus communis „gräfin von paris“' 'pyrus communis „pastorenbirne“'
#  'pyrus communis „boscs flaschenbirne“']
# --------------------------------------------------
# Genus: quercus
# 14
# ['quercus robur' 'quercus rubra' 'quercus species' 'quercus petraea'
#  'quercus palustris' 'quercus frainetto'
#  'quercus x turneri „pseudoturneri“' 'quercus cerris'
#  'quercus robur „fastigiata koster“' 'quercus robur „fastigiata“'
#  'quercus rubra „aurea“' 'quercus palustris „crownright“'
#  'quercus coccinea' 'quercus robur „fastigiata aurea“']
# --------------------------------------------------
# Genus: rhamnus
# 1
# ['rhamnus species']
# --------------------------------------------------
# Genus: rhus
# 2
# ['rhus typhina' 'rhus species']
# --------------------------------------------------
# Genus: robinia
# 9
# ['robinia pseudoacacia „nyirsegi“' 'robinia pseudoacacia'
#  'robinia species' 'robinia pseudoacacia „semperflorens“'
#  'robinia pseudoacacia „bessoniana“'
#  'robinia pseudoacacia „umbraculifera“'
#  'robinia pseudoacacia „casque rouge“'
#  'robinia pseudoacacia „monophylla fastigiata“' 'robinia hispida']
# --------------------------------------------------
# Genus: salix
# 12
# ['salix species' 'salix alba' 'salix alba „tristis“' 'salix fragilis'
#  'salix caprea' 'salix matsudana „tortuosa“' 'salix aurita'
#  'salix alba „liempde“' 'salix alba „tristis resistenta“' 'salix nigra'
#  'salix babylonica' 'salix viminalis']
# --------------------------------------------------
# Genus: sambucus
# 2
# ['sambucus nigra' 'sambucus species']
# --------------------------------------------------
# Genus: sequoia
# 1
# ['sequoia sempervirens']
# --------------------------------------------------
# Genus: sequoiadendron
# 1
# ['sequoiadendron giganteum']
# --------------------------------------------------
# Genus: sophora
# 2
# ['sophora japonica' 'sophora „uprise“']
# --------------------------------------------------
# Genus: sorbaria
# 1
# ['sorbaria sorbifolia']
# --------------------------------------------------
# Genus: sorbus
# 10
# ['sorbus aria' 'sorbus intermedia „brouwers“' 'sorbus intermedia'
#  'sorbus aucuparia' 'sorbus torminalis' 'sorbus aria „magnifica“'
#  'sorbus species' 'sorbus domestica' 'sorbus aucuparia „fastigata“'
#  'sorbus latifolia „henk vink“']
# --------------------------------------------------
# Genus: species
# 1
# ['verschiedene oder baumart unbekannt']
# --------------------------------------------------
# Genus: styrax
# 1
# ['styrax japonica']
# --------------------------------------------------
# Genus: syringa
# 1
# ['syringa vulgaris']
# --------------------------------------------------
# Genus: tamarix
# 1
# ['tamarix pentandra']
# --------------------------------------------------
# Genus: taxodium
# 1
# ['taxodium distichum']
# --------------------------------------------------
# Genus: taxus
# 3
# ['taxus species' 'taxus baccata' 'taxus cuspidata']
# --------------------------------------------------
# Genus: tetradium
# 1
# ['tetradium daniellii']
# --------------------------------------------------
# Genus: thuja
# 5
# ['thuja occidentalis' 'thuja plicata' 'thuja species' 'thuja orientalis'
#  'thuja occidentalis „columna“']
# --------------------------------------------------
# Genus: tilia
# 18
# ['tilia cordata' 'tilia platyphyllos' 'tilia cordata „greenspire“'
#  'tilia species' 'tilia tomentosa „brabant“' 'tilia oliveri'
#  'tilia vulgaris „pallida“' 'tilia tomentosa' 'tilia x euchlora'
#  'tilia americana' 'tilia cordata „rancho“' 'tilia cordata „erecta“'
#  'tilia x intermedia' 'tilia x europaea' 'tilia tomentosa „szeleste“'
#  'tilia cordata „roelvo“' 'tilia americana „nova“'
#  'tilia cordata „glenleven“']
# --------------------------------------------------
# Genus: tsuga
# 2
# ['tsuga canadensis' 'tsuga mertensiana']
# --------------------------------------------------
# Genus: ulmus
# 14
# ['ulmus laevis' 'ulmus „new horizon“' 'ulmus species' 'ulmus glabra'
#  'ulmus glabra „exoniensis“' 'ulmus carpinifolia' 'ulmus procera'
#  'ulmus „regal“' 'ulmus glabra „pendula“' 'ulmus glabra „lutescens“'
#  'ulmus „rebona“' 'ulmus „lobel“' 'ulmus carpinifolia „wredei“'
#  'ulmus x hollandica „commelin“']
# --------------------------------------------------
# Genus: viburnum
# 2
# ['viburnum rhytidophyllum' 'viburnum dentatum']
# --------------------------------------------------
# Genus: zelkova
# 1
# ['zelkova serrata']
# --------------------------------------------------

# %% [markdown]
# <h3 style="color: #ec300e;">Cleaning Categories in "genus" and "species"</h3>

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #f7b70d;
#     border-radius: 4px;
#     background-color: #e2ee1e;
#     color: #060606;
#     font-size: 16px;
#     line-height: 1.5;
#     word-wrap: break-word;
#     text-align: left;">
#     <strong>Next Steps:</strong>
#     <p>After looking at the values from species, which is a subcategory of genus, I will make some changes to the category name and genuss in species in order to have unambiguous and clearly delineated data in that column. I gave the above list to ChatGPT to find irregularities or unclear or doubled data. These are the steps I will undertake:</p>
#     <ol>
#         <li>Erase unclear data (words like various, tree species unknown or aggregate).</li>
#         <li>Check entries in species containing the word "species" and the category from genus, and specify these.</li>
#         <li>Remove varieties (often marked with quotation marks) from entries containing genus, species, and variety, to ensure consistent data with only genus and species.</li>
#         <li>Erase quotation marks (if any remain after the previous step).</li>
#         <li>Correct incorrect entries (using ChatGPT to check all entries for typos).</li>
#     </ol>
# </div>

# %% [markdown]
# <h4 style="color: #bb1010;">1.) Erase unclear data</h4>

# %%
# one category in genus is called "species" and it only contains one value which translated means "various or tree species unknown"
df3[df3.genus == "species"]
# Out:
#         lat  long    genus                              species  alley_tree  \
# 111   54.11 12.15  species  verschiedene oder baumart unbekannt           0
# 1107  54.07 12.14  species  verschiedene oder baumart unbekannt           0
# 1115  54.08 12.07  species  verschiedene oder baumart unbekannt           0
# 1156  54.07 12.08  species  verschiedene oder baumart unbekannt           0
# 1227  54.07 12.14  species  verschiedene oder baumart unbekannt           0
# ...     ...   ...      ...                                  ...         ...
# 68021 54.10 12.17  species  verschiedene oder baumart unbekannt           0
# 68022 54.10 12.17  species  verschiedene oder baumart unbekannt           0
# 68023 54.10 12.17  species  verschiedene oder baumart unbekannt           0
# 68024 54.10 12.17  species  verschiedene oder baumart unbekannt           0
# 70440 54.11 12.06  species  verschiedene oder baumart unbekannt           0
#
#        height  trunk_circumference  crown_diameter  sponsorship
# 111       NaN                  NaN             NaN            0
# 1107      NaN                  NaN             NaN            0
# 1115      NaN                  NaN             NaN            0
# 1156    12.00                 0.79            2.00            0
# 1227      NaN                  NaN             NaN            0
# ...       ...                  ...             ...          ...
# 68021     NaN                  NaN             NaN            0
# 68022     NaN                  NaN             NaN            0
# 68023     NaN                  NaN             NaN            0
# 68024     NaN                  NaN             NaN            0
# 70440     NaN                  NaN             NaN            0
#
# [216 rows x 9 columns]

# %%
# rows containg the value "Species" in the column "genus" will be dropped as they contain no information which can be connected to a specific tree
df3 = df3[df3['genus'] != 'species']

# resetting the index (dropping the old one)
df3.reset_index(drop=True, inplace=True)

# %%
# another category in "genus" is called "gruppenbäume" which means "group trees". The categories in column "species" belonging to this category are very diverse (different species of trees in one cell etc.) 
df3[df3['genus'] == 'gruppenbäume']
# Out:
#         lat  long         genus                       species  alley_tree  \
# 5     54.11 12.15  gruppenbäume   fichten-kiefer-mischbestand           0
# 6     54.13 12.05  gruppenbäume  windschutz laub-mischbestand           0
# 7     54.07 12.11  gruppenbäume       ahorn-laub-mischbestand           0
# 23    54.07 12.18  gruppenbäume   fichten-kiefer-mischbestand           0
# 118   54.07 12.11  gruppenbäume   bruchwald erle mischbestand           0
# ...     ...   ...           ...                           ...         ...
# 70617 54.11 12.15  gruppenbäume                  erlenbestand           0
# 70659 54.10 12.17  gruppenbäume  windschutz laub-mischbestand           0
# 70691 54.11 12.16  gruppenbäume   bruchwald erle mischbestand           0
# 70695 54.07 12.11  gruppenbäume        lärchen-laub-mischwald           0
# 70722 54.10 12.15  gruppenbäume       weichholz-weidenbestand           0
#
#        height  trunk_circumference  crown_diameter  sponsorship
# 5       20.00                 1.60            1.00            0
# 6         NaN                  NaN             NaN            0
# 7         NaN                 0.79             NaN            0
# 23      21.00                 3.02            1.00            0
# 118     13.00                 0.79            4.00            0
# ...       ...                  ...             ...          ...
# 70617   18.00                 1.26            6.00            0
# 70659   13.00                 0.91            1.00            0
# 70691   20.00                 1.89           12.00            0
# 70695   27.00                 2.10            9.00            0
# 70722   15.00                 1.32            1.00            0
#
# [1254 rows x 9 columns]

# %%
# this category of "genus" will be dropped as is not useful for this analysis because it cannot be connected to a specific type of tree
df3 = df3[df3['genus'] != 'gruppenbäume']

# resetting the index (dropping the old one)
df3.reset_index(drop=True, inplace=True)

# %% [markdown]
# <h4 style="color: #bb1010;">2.) Clean doubled data</h4>

# %%
df3[df3["species"].str.contains("species", na=False)].sample(10)
# Out:
#         lat  long     genus           species  alley_tree  height  \
# 22400 54.14 12.07  platanus  platanus species           0   10.00
# 15296 54.17 12.08     tilia     tilia species           0   12.00
# 50780 54.08 12.12   quercus   quercus species           0   30.00
# 39957 54.17 12.05     malus     malus species           0    9.00
# 15474 54.08 12.12     tilia     tilia species           0   29.00
# 33399 54.08 12.18      acer      acer species           0   14.50
# 10335 54.15 12.08  platanus  platanus species           0    9.00
# 6576  54.15 12.18     salix     salix species           0    6.00
# 61323 54.18 12.22     picea     picea species           0   17.00
# 35897 54.13 12.07   quercus   quercus species           0   10.00
#
#        trunk_circumference  crown_diameter  sponsorship
# 22400                 0.82            1.00            0
# 15296                 1.51            1.00            0
# 50780                 1.75            2.20            0
# 39957                 0.88            6.00            0
# 15474                 2.07            1.00            0
# 33399                 0.63            7.00            0
# 10335                 0.82            1.00            0
# 6576                  0.28            3.15            0
# 61323                 1.36            7.00            0
# 35897                 0.96            2.20            0

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #b8daff;
#     border-radius: 4px;
#     background-color: #0eece8;
#     color: #004085;
#     font-size: 16px;
#     line-height: 1.5;
#     word-wrap: break-word;
#     text-align: left;">
#     <strong>Conclusions: Doubled Data in genus and species</strong>
# <p>After checking the occurence of the word "species" in the column of the same name, it becomes clear that there is no additional info in these cells compared to the info already provided in the column genus. Yet, there is also no harm in this data for now and the info in species is needed for the replacement of outliers (above) and might also be needed for handling null values (below), so I will keep the data as it is at the moment and simply erase the word "species" from the column because this is unnecessary.</p>
# </div>

# %%
# Erasing the word "species" whilst making sure that only this exact word is taken away.
# Also cleaning cells of all unnecessary empty spaces
df3["species"] = df3["species"].str.replace("species", "", regex=False).str.strip()

# %% [markdown]
# <h4 style="color: #bb1010;">3.) Remove Subcategories of Species</h4>
#
# As explained in the box above ("Next Steps"), these varieties seem to be marked with quotation marks

# %%
df3.shape
# Out:
# (69599, 9)

# %%
df3[df3["species"].str.contains("„", na=False)]
# Out:
#         lat  long  genus                        species  alley_tree  height  \
# 7     54.09 12.10  tilia     tilia cordata „greenspire“           0    5.00
# 10    54.08 12.13  tilia     tilia cordata „greenspire“           0    6.00
# 13    54.09 12.10  tilia     tilia cordata „greenspire“           0    5.00
# 25    54.15 12.08  tilia     tilia cordata „greenspire“           1    8.00
# 38    54.08 12.17   acer  acer pseudoplatanus „bruchem“           1     NaN
# ...     ...   ...    ...                            ...         ...     ...
# 69475 54.09 12.11  tilia     tilia cordata „greenspire“           0    6.00
# 69499 54.09 12.11  tilia     tilia cordata „greenspire“           0    6.00
# 69581 54.07 12.11  picea         picea pungens „glauca“           0   15.00
# 69582 54.07 12.11  picea         picea pungens „glauca“           0   15.00
# 69583 54.07 12.11  picea         picea pungens „glauca“           0   16.00
#
#        trunk_circumference  crown_diameter  sponsorship
# 7                     0.20            1.00            0
# 10                    0.38            3.00            0
# 13                    0.20            1.00            0
# 25                    0.44            4.00            0
# 38                     NaN             NaN            0
# ...                    ...             ...          ...
# 69475                 0.39            2.00            0
# 69499                 0.33           15.00            0
# 69581                 1.04            5.00            0
# 69582                 0.15            5.00            0
# 69583                 1.40            6.00            0
#
# [4969 rows x 9 columns]

# %%
df3[df3["species"].str.contains("greenspire", na=False)]
# Out:
#         lat  long  genus                     species  alley_tree  height  \
# 7     54.09 12.10  tilia  tilia cordata „greenspire“           0    5.00
# 10    54.08 12.13  tilia  tilia cordata „greenspire“           0    6.00
# 13    54.09 12.10  tilia  tilia cordata „greenspire“           0    5.00
# 25    54.15 12.08  tilia  tilia cordata „greenspire“           1    8.00
# 51    54.08 12.14  tilia  tilia cordata „greenspire“           0     NaN
# ...     ...   ...    ...                         ...         ...     ...
# 69390 54.09 12.11  tilia  tilia cordata „greenspire“           0    5.00
# 69473 54.09 12.11  tilia  tilia cordata „greenspire“           0    5.00
# 69474 54.09 12.11  tilia  tilia cordata „greenspire“           0    6.00
# 69475 54.09 12.11  tilia  tilia cordata „greenspire“           0    6.00
# 69499 54.09 12.11  tilia  tilia cordata „greenspire“           0    6.00
#
#        trunk_circumference  crown_diameter  sponsorship
# 7                     0.20            1.00            0
# 10                    0.38            3.00            0
# 13                    0.20            1.00            0
# 25                    0.44            4.00            0
# 51                     NaN            5.00            0
# ...                    ...             ...          ...
# 69390                 0.26            1.50            0
# 69473                 0.30            1.50            0
# 69474                 0.39            2.00            0
# 69475                 0.39            2.00            0
# 69499                 0.33           15.00            0
#
# [527 rows x 9 columns]

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #b8daff;
#     border-radius: 4px;
#     background-color: #0eece8;
#     color: #004085;
#     font-size: 16px;
#     line-height: 1.5;
#     word-wrap: break-word;
#     text-align: left;">
#     <strong>Conclusions: Subcategories/ Varieties of Tree Species</strong>
# <p>After seeing the number of occurences of subcategories of a species (almost 5,000 rows out of a total 70,000), I decided to make use of this data to be able to analyze later that specific variety of tree species and what impact it might have. I will therefore create a new column called "variety" and will transfer all info from column species to the new column. All cells where there is no subcategory to be found, I will for now encode as "0".</p>
# </div>

# %%
# copying entries in "species" to new column "variety", if there are quotation marks in "species", else set "0" in "variety"
df3['variety'] = df3['species'].where(df3['species'].str.contains(r'[„“]', regex=True), '0')

# cleaning "species" from quotation marks and values inside them
df3['species'] = df3['species'].str.replace(r'„.*?“', '', regex=True).str.strip()

# cleaning quotations marks in "variety"
df3['variety'] = df3['variety'].str.replace(r'[„“]', '', regex=True).str.strip()

df3[:15]
# Out:
#      lat  long    genus              species  alley_tree  height  \
# 0  54.06 12.10     acer     acer platanoides           0    8.00
# 1  54.05 12.10     acer     acer platanoides           0    8.00
# 2  54.07 12.12  quercus        quercus robur           0   18.00
# 3  54.07 12.11     acer       acer saccharum           0   20.00
# 4  54.07 12.12  quercus        quercus rubra           1    9.00
# 5  54.16 12.08    tilia        tilia cordata           1    7.00
# 6  54.13 12.05    tilia   tilia platyphyllos           1    8.00
# 7  54.09 12.10    tilia        tilia cordata           0    5.00
# 8  54.08 12.19     acer  acer pseudoplatanus           0   11.00
# 9  54.13 12.07  quercus              quercus           0    3.00
# 10 54.08 12.13    tilia        tilia cordata           0    6.00
# 11 54.06 12.10     acer  acer pseudoplatanus           0    7.00
# 12 54.08 12.09     acer                 acer           0   18.00
# 13 54.09 12.10    tilia        tilia cordata           0    5.00
# 14 54.09 12.15   betula               betula           0   11.00
#
#     trunk_circumference  crown_diameter  sponsorship                   variety
# 0                   NaN            6.00            0                         0
# 1                   NaN            6.00            0                         0
# 2                  1.10            2.00            0                         0
# 3                  1.60             NaN            0                         0
# 4                  1.00            2.00            0                         0
# 5                  0.38            3.00            0                         0
# 6                  0.82            3.00            0                         0
# 7                  0.20            1.00            0  tilia cordata greenspire
# 8                  1.40            5.00            0                         0
# 9                  0.41            1.00            0                         0
# 10                 0.38            3.00            0  tilia cordata greenspire
# 11                 0.63            3.00            0                         0
# 12                 1.10            8.00            0                         0
# 13                 0.20            1.00            0  tilia cordata greenspire
# 14                 0.47            3.50            0                         0

# %% [markdown]
# <h2 style="color: #ec7511;">Checking Null Values</h2>

# %%
df3.isna().sum()
# Out:
# lat                       0
# long                      0
# genus                     0
# species                   0
# alley_tree                0
# height                 1183
# trunk_circumference    1444
# crown_diameter         1539
# sponsorship               0
# variety                   0
# dtype: int64

# %%
df3
# Out:
#         lat  long    genus               species  alley_tree  height  \
# 0     54.06 12.10     acer      acer platanoides           0    8.00
# 1     54.05 12.10     acer      acer platanoides           0    8.00
# 2     54.07 12.12  quercus         quercus robur           0   18.00
# 3     54.07 12.11     acer        acer saccharum           0   20.00
# 4     54.07 12.12  quercus         quercus rubra           1    9.00
# ...     ...   ...      ...                   ...         ...     ...
# 69594 54.19 12.15  quercus         quercus robur           0   25.00
# 69595 54.19 12.15  quercus         quercus robur           0   15.00
# 69596 54.08 12.19   prunus          prunus avium           0   13.00
# 69597 54.20 12.15    pinus      pinus sylvestris           0   19.00
# 69598 54.19 12.35  robinia  robinia pseudoacacia           0   20.00
#
#        trunk_circumference  crown_diameter  sponsorship variety
# 0                      NaN            6.00            0       0
# 1                      NaN            6.00            0       0
# 2                     1.10            2.00            0       0
# 3                     1.60             NaN            0       0
# 4                     1.00            2.00            0       0
# ...                    ...             ...          ...     ...
# 69594                 2.40            2.00            0       0
# 69595                 2.23            2.00            0       0
# 69596                 1.52            1.00            0       0
# 69597                 1.58            7.00            0       0
# 69598                 2.96            1.00            0       0
#
# [69599 rows x 10 columns]

# %%
print(f"The proportion of NaNs in height: {round(df3.height.isnull().sum() / len(df3) * 100, 2)} %")
print(f"The proportion of NaNs in trunk_circumference: {round(df3.trunk_circumference.isnull().sum() / len(df3) * 100, 2)} %")
print(f"The proportion of NaNs in crown_diameter: {round(df3.crown_diameter.isnull().sum() / len(df3) * 100, 2)} %")
# Out:
# The proportion of NaNs in height: 1.7 %
# The proportion of NaNs in trunk_circumference: 2.07 %
# The proportion of NaNs in crown_diameter: 2.21 %

# %% [markdown]
# <h3 style="color: #ec300e;">How to Handle Null Values</h3>
#
# I will be trying to handle null values with giving up as little data as possible:
# - As the missing values are all in numerical columns, and the parameters are most likely related to the tree genus/ species, my aim is to **replace the missing values with mean or median of the columns per subgroup (genus or species of tree, tbd)**.
# - If this is justifiable will be dependent on the data foundation in each subgroup, therefore, I will be checking first the species and then the genus and the **share of NaNs in each subgroup**.
# - Preferably, I would replace the NaNs with median/mean values from **species** because this is the smaller-scaled variable (genus is the superordinate category of species).

# %% [markdown]
# <h4 style="color: #bb1010;">Null values per Species</h4>

# %%
# checking the share of NaNs for each column with NaNs per category in species

# storing total number of values in each species in a variable
species_values = df3['species'].value_counts()

# creating a dataframe to evaluate total values and share of NaNs (per species) for each column with NaNs
nan_summary_species_height = pd.DataFrame({
    "total_values_in_species": species_values,
    "nan_values_height_per_species": df3[df3['height'].isna()]['species'].value_counts()
}).fillna(0)
nan_summary_species_trunk_circumference = pd.DataFrame({
    "total_values_in_species": species_values,
    "nan_values_trunk_circumference_per_species": df3[df3['trunk_circumference'].isna()]['species'].value_counts()
}).fillna(0)
nan_summary_species_crown_diameter = pd.DataFrame({
    "total_values_in_species": species_values,
    "nan_values_crown_diameter_per_species": df3[df3['crown_diameter'].isna()]['species'].value_counts()
}).fillna(0)

nan_summary_species_height["share_of_nan_in_height_per_species"] = (nan_summary_species_height["nan_values_height_per_species"]
                                                  / nan_summary_species_height["total_values_in_species"])
nan_summary_species_trunk_circumference["share_of_nan_in_trunk_circumference_per_species"] = (nan_summary_species_trunk_circumference["nan_values_trunk_circumference_per_species"]
                                                  / nan_summary_species_trunk_circumference["total_values_in_species"])
nan_summary_species_crown_diameter["share_of_nan_in_crown_diameter_per_species"] = (nan_summary_species_crown_diameter["nan_values_crown_diameter_per_species"]
                                                  / nan_summary_species_crown_diameter["total_values_in_species"])

# %%
df3
# Out:
#         lat  long    genus               species  alley_tree  height  \
# 0     54.06 12.10     acer      acer platanoides           0    8.00
# 1     54.05 12.10     acer      acer platanoides           0    8.00
# 2     54.07 12.12  quercus         quercus robur           0   18.00
# 3     54.07 12.11     acer        acer saccharum           0   20.00
# 4     54.07 12.12  quercus         quercus rubra           1    9.00
# ...     ...   ...      ...                   ...         ...     ...
# 69594 54.19 12.15  quercus         quercus robur           0   25.00
# 69595 54.19 12.15  quercus         quercus robur           0   15.00
# 69596 54.08 12.19   prunus          prunus avium           0   13.00
# 69597 54.20 12.15    pinus      pinus sylvestris           0   19.00
# 69598 54.19 12.35  robinia  robinia pseudoacacia           0   20.00
#
#        trunk_circumference  crown_diameter  sponsorship variety
# 0                      NaN            6.00            0       0
# 1                      NaN            6.00            0       0
# 2                     1.10            2.00            0       0
# 3                     1.60             NaN            0       0
# 4                     1.00            2.00            0       0
# ...                    ...             ...          ...     ...
# 69594                 2.40            2.00            0       0
# 69595                 2.23            2.00            0       0
# 69596                 1.52            1.00            0       0
# 69597                 1.58            7.00            0       0
# 69598                 2.96            1.00            0       0
#
# [69599 rows x 10 columns]

# %%
# displaying share of NaNs in height per species
nan_summary_species_height.sort_values("share_of_nan_in_height_per_species", ascending=False)[:7]
# Out:
#                          total_values_in_species  \
# species
# viburnum dentatum                              2
# broussonetia papyrifera                        1
# prunus armeniaca                               1
# tilia oliveri                                  1
# salix nigra                                   31
# laburnum                                       3
# tilia x europaea                              30
#
#                          nan_values_height_per_species  \
# species
# viburnum dentatum                                 2.00
# broussonetia papyrifera                           1.00
# prunus armeniaca                                  1.00
# tilia oliveri                                     1.00
# salix nigra                                      12.00
# laburnum                                          1.00
# tilia x europaea                                  7.00
#
#                          share_of_nan_in_height_per_species
# species
# viburnum dentatum                                      1.00
# broussonetia papyrifera                                1.00
# prunus armeniaca                                       1.00
# tilia oliveri                                          1.00
# salix nigra                                            0.39
# laburnum                                               0.33
# tilia x europaea                                       0.23

# %%
# displaying share of NaNs in trunk_circumference per species
nan_summary_species_trunk_circumference.sort_values("share_of_nan_in_trunk_circumference_per_species", ascending=False)[:7]
# Out:
#                          total_values_in_species  \
# species
# tilia oliveri                                  1
# viburnum dentatum                              2
# prunus armeniaca                               1
# broussonetia papyrifera                        1
# malus domenstica                               6
# salix nigra                                   31
# tilia x europaea                              30
#
#                          nan_values_trunk_circumference_per_species  \
# species
# tilia oliveri                                                  1.00
# viburnum dentatum                                              2.00
# prunus armeniaca                                               1.00
# broussonetia papyrifera                                        1.00
# malus domenstica                                               4.00
# salix nigra                                                   12.00
# tilia x europaea                                               7.00
#
#                          share_of_nan_in_trunk_circumference_per_species
# species
# tilia oliveri                                                       1.00
# viburnum dentatum                                                   1.00
# prunus armeniaca                                                    1.00
# broussonetia papyrifera                                             1.00
# malus domenstica                                                    0.67
# salix nigra                                                         0.39
# tilia x europaea                                                    0.23

# %%
# displaying share of NaNs in crown_diameter per species
nan_summary_species_crown_diameter.sort_values("share_of_nan_in_crown_diameter_per_species", ascending=False)[:12]
# Out:
#                           total_values_in_species  \
# species
# salix viminalis                                 3
# broussonetia papyrifera                         1
# hedera helix                                    1
# tilia oliveri                                   1
# larix x eurolepsis                              1
# populus lasiocarpa                              3
# sequoiadendron giganteum                        7
# larix kaempferi                                95
# acer saccharum                                 29
# acer carpinifolium                             17
# prunus mahaleb                                 17
# platanus hispanica                              1
#
#                           nan_values_crown_diameter_per_species  \
# species
# salix viminalis                                            3.00
# broussonetia papyrifera                                    1.00
# hedera helix                                               1.00
# tilia oliveri                                              1.00
# larix x eurolepsis                                         1.00
# populus lasiocarpa                                         3.00
# sequoiadendron giganteum                                   7.00
# larix kaempferi                                           95.00
# acer saccharum                                            29.00
# acer carpinifolium                                        17.00
# prunus mahaleb                                            17.00
# platanus hispanica                                         1.00
#
#                           share_of_nan_in_crown_diameter_per_species
# species
# salix viminalis                                                 1.00
# broussonetia papyrifera                                         1.00
# hedera helix                                                    1.00
# tilia oliveri                                                   1.00
# larix x eurolepsis                                              1.00
# populus lasiocarpa                                              1.00
# sequoiadendron giganteum                                        1.00
# larix kaempferi                                                 1.00
# acer saccharum                                                  1.00
# acer carpinifolium                                              1.00
# prunus mahaleb                                                  1.00
# platanus hispanica                                              1.00

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #b8daff;
#     border-radius: 4px;
#     background-color: #0eece8;
#     color: #004085;
#     font-size: 16px;">
#     <strong>Conclusions:</strong> There are many categories in "species" which have a high share of NaNs regarding the respective column. Yet, many of them contain only a few values at all. So, if I in the end decide not to fill up the NaNs, there will most likely not be a significant loss of data.
# </div>

# %% [markdown]
# <h4 style="color: #bb1010;">Conditional Replacement of Tree Metrics with Median</h4>

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #f7b70d;
#     border-radius: 4px;
#     background-color: #e2ee1e;
#     color: #060606;
#     font-size: 16px;
#     line-height: 1.5;
#     word-wrap: break-word;
#     text-align: left;">
#     <strong>Next Steps:</strong>
# <p>If the share of NaNs in that species is <strong>less than 25 %</strong>, I will replace it with the median value of that species.</p>
# </div>

# %%
# calculating median of height, trunk_circumference and crown_diameter per species
median_values = df3.groupby('species')[['height', 'trunk_circumference', 'crown_diameter']].median()

# function to replace NaNs with the median of the respective category if share of NaNs in that category is not greater than 25 %
def replace_nans_with_median(group):
    nan_ratio = group.isna().mean()  # output of this is share of NaNs in that specific group
    if nan_ratio['height'] <= 0.25:
        group['height'] = group['height'].fillna(median_values.loc[group.name, 'height'])
    if nan_ratio['trunk_circumference'] <= 0.25:
        group['trunk_circumference'] = group['trunk_circumference'].fillna(median_values.loc[group.name, 'trunk_circumference'])
    if nan_ratio['crown_diameter'] <= 0.25:
        group['crown_diameter'] = group['crown_diameter'].fillna(median_values.loc[group.name, 'crown_diameter'])
    return group

# applying function to each category in "species" and keeping the old index
df3 = df3.groupby('species', group_keys=False).apply(replace_nans_with_median)

# %%
df3[:15]
# Out:
#      lat  long    genus              species  alley_tree  height  \
# 0  54.06 12.10     acer     acer platanoides           0    8.00
# 1  54.05 12.10     acer     acer platanoides           0    8.00
# 2  54.07 12.12  quercus        quercus robur           0   18.00
# 3  54.07 12.11     acer       acer saccharum           0   20.00
# 4  54.07 12.12  quercus        quercus rubra           1    9.00
# 5  54.16 12.08    tilia        tilia cordata           1    7.00
# 6  54.13 12.05    tilia   tilia platyphyllos           1    8.00
# 7  54.09 12.10    tilia        tilia cordata           0    5.00
# 8  54.08 12.19     acer  acer pseudoplatanus           0   11.00
# 9  54.13 12.07  quercus              quercus           0    3.00
# 10 54.08 12.13    tilia        tilia cordata           0    6.00
# 11 54.06 12.10     acer  acer pseudoplatanus           0    7.00
# 12 54.08 12.09     acer                 acer           0   18.00
# 13 54.09 12.10    tilia        tilia cordata           0    5.00
# 14 54.09 12.15   betula               betula           0   11.00
#
#     trunk_circumference  crown_diameter  sponsorship                   variety
# 0                  0.69            6.00            0                         0
# 1                  0.69            6.00            0                         0
# 2                  1.10            2.00            0                         0
# 3                  1.60             NaN            0                         0
# 4                  1.00            2.00            0                         0
# 5                  0.38            3.00            0                         0
# 6                  0.82            3.00            0                         0
# 7                  0.20            1.00            0  tilia cordata greenspire
# 8                  1.40            5.00            0                         0
# 9                  0.41            1.00            0                         0
# 10                 0.38            3.00            0  tilia cordata greenspire
# 11                 0.63            3.00            0                         0
# 12                 1.10            8.00            0                         0
# 13                 0.20            1.00            0  tilia cordata greenspire
# 14                 0.47            3.50            0                         0

# %%
df3.isna().sum()
# Out:
# lat                      0
# long                     0
# genus                    0
# species                  0
# alley_tree               0
# height                  18
# trunk_circumference     21
# crown_diameter         314
# sponsorship              0
# variety                  0
# dtype: int64

# %% [markdown]
# <h4 style="color: #bb1010;">Dropping the Remaining NaNs</h4>

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #b8daff;
#     border-radius: 4px;
#     background-color: #0eece8;
#     color: #004085;
#     font-size: 16px;">
#     <strong>Conclusions:</strong>
#     <p>For the remaining NaNs there is not enough data basis to replace them with other values. There are simply not enough valid values in the specific same category of "species" to do this. Therefore, I decided to drop the remaining NaNs. Also, there is not many left, so the data loss will be minimal.</p>
# </div>

# %%
df3.shape
# Out:
# (69599, 10)

# %%
df3.dropna(axis=0, inplace=True)

# %%
df3.isna().sum()
# Out:
# lat                    0
# long                   0
# genus                  0
# species                0
# alley_tree             0
# height                 0
# trunk_circumference    0
# crown_diameter         0
# sponsorship            0
# variety                0
# dtype: int64

# %%
df3.shape
# Out:
# (69285, 10)

# %%
df3.reset_index()
df3
# Out:
#         lat  long    genus               species  alley_tree  height  \
# 0     54.06 12.10     acer      acer platanoides           0    8.00
# 1     54.05 12.10     acer      acer platanoides           0    8.00
# 2     54.07 12.12  quercus         quercus robur           0   18.00
# 4     54.07 12.12  quercus         quercus rubra           1    9.00
# 5     54.16 12.08    tilia         tilia cordata           1    7.00
# ...     ...   ...      ...                   ...         ...     ...
# 69594 54.19 12.15  quercus         quercus robur           0   25.00
# 69595 54.19 12.15  quercus         quercus robur           0   15.00
# 69596 54.08 12.19   prunus          prunus avium           0   13.00
# 69597 54.20 12.15    pinus      pinus sylvestris           0   19.00
# 69598 54.19 12.35  robinia  robinia pseudoacacia           0   20.00
#
#        trunk_circumference  crown_diameter  sponsorship variety
# 0                     0.69            6.00            0       0
# 1                     0.69            6.00            0       0
# 2                     1.10            2.00            0       0
# 4                     1.00            2.00            0       0
# 5                     0.38            3.00            0       0
# ...                    ...             ...          ...     ...
# 69594                 2.40            2.00            0       0
# 69595                 2.23            2.00            0       0
# 69596                 1.52            1.00            0       0
# 69597                 1.58            7.00            0       0
# 69598                 2.96            1.00            0       0
#
# [69285 rows x 10 columns]

# %% [markdown]
# <h2 style="color: #ec7511;">Checking Duplicates</h2>

# %%
df3.duplicated().sum()
# Out:
# 1

# %%
# taking a look at the duplicates
df3[df3.duplicated(keep=False)]
# Out:
#         lat  long    genus        species  alley_tree  height  \
# 26378 54.13 12.05  populus  populus nigra           0   30.00
# 26379 54.13 12.05  populus  populus nigra           0   30.00
#
#        trunk_circumference  crown_diameter  sponsorship                variety
# 26378                 1.16            2.00            0  populus nigra italica
# 26379                 1.16            2.00            0  populus nigra italica

# %%
# checking the original df to see if this for certain is a duplicate (=same unique identifier)
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #b8daff;
#     border-radius: 4px;
#     background-color: #0eece8;
#     color: #004085;
#     font-size: 16px;">
#     <strong>Conclusions:</strong>
#     <p>Even though, the two rows have different unique IDs, I would argue that it is highly unlikely to have two trees with the exact same indicators at the very same location. Therefore, I will drop the duplicate.</p>
# </div>

# %%
df3.drop_duplicates(inplace=True)

# %%
df3.shape
# Out:
# (69284, 10)

# %% [markdown]
# <h2 style="color: #ec7511;">Checking Empty Spaces</h2>

# %%
df3.eq(" ").sum()
# Out:
# lat                    0
# long                   0
# genus                  0
# species                0
# alley_tree             0
# height                 0
# trunk_circumference    0
# crown_diameter         0
# sponsorship            0
# variety                0
# dtype: int64

# %% [markdown]
# <h1 style="color: #e3db24;">03 | Converting Cleaned Dataframe to csv</h1>

# %%
df3
# Out:
#         lat  long    genus               species  alley_tree  height  \
# 0     54.06 12.10     acer      acer platanoides           0    8.00
# 1     54.05 12.10     acer      acer platanoides           0    8.00
# 2     54.07 12.12  quercus         quercus robur           0   18.00
# 4     54.07 12.12  quercus         quercus rubra           1    9.00
# 5     54.16 12.08    tilia         tilia cordata           1    7.00
# ...     ...   ...      ...                   ...         ...     ...
# 69594 54.19 12.15  quercus         quercus robur           0   25.00
# 69595 54.19 12.15  quercus         quercus robur           0   15.00
# 69596 54.08 12.19   prunus          prunus avium           0   13.00
# 69597 54.20 12.15    pinus      pinus sylvestris           0   19.00
# 69598 54.19 12.35  robinia  robinia pseudoacacia           0   20.00
#
#        trunk_circumference  crown_diameter  sponsorship variety
# 0                     0.69            6.00            0       0
# 1                     0.69            6.00            0       0
# 2                     1.10            2.00            0       0
# 4                     1.00            2.00            0       0
# 5                     0.38            3.00            0       0
# ...                    ...             ...          ...     ...
# 69594                 2.40            2.00            0       0
# 69595                 2.23            2.00            0       0
# 69596                 1.52            1.00            0       0
# 69597                 1.58            7.00            0       0
# 69598                 2.96            1.00            0       0
#
# [69284 rows x 10 columns]

# %%
df3.to_csv("dataframes/df3_trees.csv", index=False) # saving data as csv, no new index

# %% [markdown]
# <div style="
#     padding: 15px;
#     margin: 10px 0;
#     border: 1px solid #f7b70d;
#     border-radius: 4px;
#     background-color: #e2ee1e;
#     color: #060606;
#     font-size: 16px;
#     line-height: 1.5;
#     word-wrap: break-word;
#     text-align: left;">
#     <strong>Outlook: EDA</strong>
# <p>In the GitHub repo, you will find another Jupyter Notebook called <strong>"eda-trees"</strong>. It contains the code for a <strong>comprehensive EDA</strong> of many of the columns (it is limited for different reasons to genus, height, trunk_circumference, crown_diameter, alley_tree and sponsorship).</p>
# </div>
